# %% [markdown]
# importing libraries

# %%
import pandas as pd

# %% [markdown]
# connecting with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# taking the path and reading csv

# %%
path="/content/drive/MyDrive/Datasets/Iris.csv"
df=pd.read_csv(path)

# %% [markdown]
# first 5 records

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# first 5 records

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %% [markdown]
# for columns and rows

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# for columns

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# datatypes

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# for null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# missing values

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %% [markdown]
# type of dataframe

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# number of values

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# decribe=columns+rows

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# to include all

# %%
df.describe(include="all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %% [markdown]
# sample observations

# %%
df.sample()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 104  105            6.5           3.0            5.8           2.2
# 37    38            4.9           3.1            1.5           0.1
# 36    37            5.5           3.5            1.3           0.2
# 133  134            6.3           2.8            5.1           1.5
# 106  107            4.9           2.5            4.5           1.7
# 67    68            5.8           2.7            4.1           1.0
# 89    90            5.5           2.5            4.0           1.3
# 99   100            5.7           2.8            4.1           1.3
# 95    96            5.7           3.0            4.2           1.2
# 10    11            5.4           3.7            1.5           0.2
#
#              Species
# 104   Iris-virginica
# 37       Iris-setosa
# 36       Iris-setosa
# 133   Iris-virginica
# 106   Iris-virginica
# 67   Iris-versicolor
# 89   Iris-versicolor
# 99   Iris-versicolor
# 95   Iris-versicolor
# ...

# %% [markdown]
# index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# columns

# %%
df.columns=["id","sepal_length","sepal_width","petal_length","petal_width","species_name"]

# %% [markdown]
# specific column

# %%
df.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df[["sepal_length","sepal_width","species_name"]]
# Out:
#      sepal_length  sepal_width    species_name
# 0             5.1          3.5     Iris-setosa
# 1             4.9          3.0     Iris-setosa
# 2             4.7          3.2     Iris-setosa
# 3             4.6          3.1     Iris-setosa
# 4             5.0          3.6     Iris-setosa
# ..            ...          ...             ...
# 145           6.7          3.0  Iris-virginica
# 146           6.3          2.5  Iris-virginica
# 147           6.5          3.0  Iris-virginica
# 148           6.2          3.4  Iris-virginica
# 149           5.9          3.0  Iris-virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# to create dataframe

# %%
df=pd.DataFrame([["Name", "Age", "Sex"],["latha",30, "female"],["lali",34, "female"]])

# %%
df
# Out:
#        0    1       2
# 0   Name  Age     Sex
# 1  latha   30  female
# 2   lali   34  female

# %%
df=pd.DataFrame([["Name", "Age", "Sex"],["latha",30, "female"],["lali",34, "female"]],columns=["Name","Age","Sex"])

# %%
df
# Out:
#     Name  Age     Sex
# 0   Name  Age     Sex
# 1  latha   30  female
# 2   lali   34  female

# %% [markdown]
# to add index

# %%
df.index=["name1","name2","name3"]
df
# Out:
#         Name  Age     Sex
# name1   Name  Age     Sex
# name2  latha   30  female
# name3   lali   34  female

# %% [markdown]
# to change column name

# %%
df.index
# Out:
# Index(['name1', 'name2', 'name3'], dtype='object')

# %% [markdown]
# to change name

# %%
df.rename(index={"name1":"name_1"})
# Out:
#          Name  Age     Sex
# name_1   Name  Age     Sex
# name2   latha   30  female
# name3    lali   34  female

# %%
df
# Out:
#         Name  Age     Sex
# name1   Name  Age     Sex
# name2  latha   30  female
# name3   lali   34  female

# %%
df.rename(index={"name1":"name_1"},inplace=True)

# %% [markdown]
# to change column name

# %%
df.rename(columns={"Name":"names"},inplace=True)
df
# Out:
#         names  Age     Sex
# name_1   Name  Age     Sex
# name2   latha   30  female
# name3    lali   34  female

# %% [markdown]
# Dataframe2

# %%
scores={"math":[34,45,56],"env":[34,45,56],"eng":[34,45,56]}
scores
# Out:
# {'math': [34, 45, 56], 'env': [34, 45, 56], 'eng': [34, 45, 56]}

# %%
df=pd.DataFrame(scores,index=["name_1","name_2","name_3"])
df
# Out:
#         math  env  eng
# name_1    34   34   34
# name_2    45   45   45
# name_3    56   56   56

# %%
df1=df[:]

# %% [markdown]
# to drop

# %%
df1.drop("name_2")
# Out:
#         math  env  eng
# name_1    34   34   34
# name_3    56   56   56

# %%
df1
# Out:
#         math  env  eng
# name_1    34   34   34
# name_2    45   45   45
# name_3    56   56   56

# %%
df1.drop("name_2",inplace=True)
# Out:
# <ipython-input-65-66bba1e7ab32>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("name_2",inplace=True)

# %%
df1
# Out:
#         math  env  eng
# name_1    34   34   34
# name_3    56   56   56

# %% [markdown]
# to drop column axis=1||||||||
# to drop row axis=0

# %%
df1.drop("eng",axis=1)
# Out:
#         math  env
# name_1    34   34
# name_3    56   56

# %%
df1.drop(["eng","env"],axis=1)
# Out:
#         math
# name_1    34
# name_3    56

# %%
df1
# Out:
#         math  env  eng
# name_1    34   34   34
# name_3    56   56   56

# %% [markdown]
# if u dont want to see the value again

# %%
df1.drop(["eng","env"],axis=1,inplace=True)
# Out:
# <ipython-input-78-4ead3ff89a0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(["eng","env"],axis=1,inplace=True)

# %%
df1
# Out:
#         math
# name_1    34
# name_3    56

# %% [markdown]
# to locate

# %%
df.loc["name_3"]
# Out:
# math    56
# env     56
# eng     56
# Name: name_3, dtype: int64

# %%
df.loc[["name_3","name_1"]]
# Out:
#         math  env  eng
# name_3    56   56   56
# name_1    34   34   34

# %% [markdown]
# to set index

# %%
df.set_index("env",inplace=True)
df
# Out:
#      math  eng
# env
# 34     34   34
# 45     45   45
# 56     56   56

# %% [markdown]
# location of row and column
# 0 stands for row and 1 stands for column

# %%
df.iloc[0,1:]
# Out:
# eng    34
# Name: 34, dtype: int64

# %%
df.iloc[1,0]
# Out:
# 45

# %%
df.iloc[[0,1],[1,0]]
# Out:
#      eng  math
# env
# 34    34    34
# 45    45    45

# %% [markdown]
# to add someother column

# %%
df["lan"]=80
df
# Out:
#      math  eng  lan
# env
# 34     34   34   80
# 45     45   45   80
# 56     56   56   80

# %%
df.loc[3]=[10,89,89]
df
# Out:
#      math  eng  lan
# env
# 34     34   34   80
# 45     45   45   80
# 56     56   56   80
# 3      10   89   89
