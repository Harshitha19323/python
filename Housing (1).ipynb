# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/drive/MyDrive/Datasets/HousePrices.csv")

# %%
data.sample()
# Out:
#       Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 931  932          20         RL         70.0     9100      Pave   NaN
#
#     Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence  \
# 931            Reg         Lvl    AllPub  ...        0    NaN  GdWo
#
#     MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# 931         NaN       0      7   2009        WD         Normal
#
#      Property_Sale_Price
# 931               117500
#
# [1 rows x 81 columns]

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.columns
# Out:
# Index(['Id', 'Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Alley', 'Property_Shape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'Dwelling_Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1460 non-null   int64
#  1   Dwell_Type           1460 non-null   int64
#  2   Zone_Class           1460 non-null   object
#  3   LotFrontage          1201 non-null   float64
#  4   LotArea              1460 non-null   int64
#  5   Road_Type            1460 non-null   object
#  6   Alley                91 non-null     object
#  7   Property_Shape       1460 non-null   object
#  8   LandContour          1460 non-null   object
#  9   Utilities            1460 non-null   object
#  10  LotConfig            1460 non-null   object
#  11  LandSlope            1460 non-null   object
#  12  Neighborhood         1460 non-null   object
#  13  Condition1           1460 non-null   object
#  14  Condition2           1460 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Id                       0
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            259
# LotArea                  0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 81, dtype: int64

# %%
data.dtypes
# Out:
# Id                       int64
# Dwell_Type               int64
# Zone_Class              object
# LotFrontage            float64
# LotArea                  int64
#                         ...
# MoSold                   int64
# YrSold                   int64
# SaleType                object
# SaleCondition           object
# Property_Sale_Price      int64
# Length: 81, dtype: object

# %%
data.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# ...

# %%
data.tail()
# Out:
#         Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 1455  1456          60         RL         62.0     7917      Pave   NaN
# 1456  1457          20         RL         85.0    13175      Pave   NaN
# 1457  1458          70         RL         66.0     9042      Pave   NaN
# 1458  1459          20         RL         68.0     9717      Pave   NaN
# 1459  1460          20         RL         75.0     9937      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# 1455            Reg         Lvl    AllPub  ...        0    NaN    NaN
# 1456            Reg         Lvl    AllPub  ...        0    NaN  MnPrv
# 1457            Reg         Lvl    AllPub  ...        0    NaN  GdPrv
# 1458            Reg         Lvl    AllPub  ...        0    NaN    NaN
# 1459            Reg         Lvl    AllPub  ...        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# ...

# %%
data.describe()
# Out:
#                 Id   Dwell_Type  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.describe(include="all").T
# Out:
#                       count unique     top  freq          mean           std  \
# Id                   1460.0    NaN     NaN   NaN         730.5    421.610009
# Dwell_Type           1460.0    NaN     NaN   NaN      56.89726     42.300571
# Zone_Class             1460      5      RL  1151           NaN           NaN
# LotFrontage          1201.0    NaN     NaN   NaN     70.049958     24.284752
# LotArea              1460.0    NaN     NaN   NaN  10516.828082   9981.264932
# ...                     ...    ...     ...   ...           ...           ...
# MoSold               1460.0    NaN     NaN   NaN      6.321918      2.703626
# YrSold               1460.0    NaN     NaN   NaN   2007.815753      1.328095
# SaleType               1460      9      WD  1267           NaN           NaN
# SaleCondition          1460      6  Normal  1198           NaN           NaN
# Property_Sale_Price  1460.0    NaN     NaN   NaN  180921.19589  79442.502883
#
# ...

# %%
sns.countplot(x="Id",data=data)
# Out:
# <Axes: xlabel='Id', ylabel='count'>

# %%
sns.countplot(x="Dwell_Type",hue="Property_Shape",data=data)

# %%
data.hist(figsize=(10,20))

# %%
sns.boxplot(x="Dwell_Type",y="SaleCondition",data=data)

# %%
sns.pairplot(data,diag_kind='kde')

# %%
pd.crosstab(data["Id",data["SaleType"]])

# %%
corr=data.corr()
corr

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
